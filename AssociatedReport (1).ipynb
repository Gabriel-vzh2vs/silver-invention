# %% [markdown]
# ### Team 21, Proposal to Optimize Profit in SOAC/Classic_Models Database
#
# Participants: Olivia
# Bernard: [<u>kdg8ac@virginia.edu</u>](mailto:kdg8ac@virginia.edu);
# Gabriel Lawrence (Majority): [<u>Gabriel</u>
# <u>Lawrence</u>](mailto:vzh2vs@virginia.edu);Camp
# Hagood: [<u>nsh4ad@virginia.edu</u>](mailto:nsh4ad@virginia.edu); Drake
# Ferri:  [<u>uvt4ct@virginia.edu</u>](mailto:uvt4ct@virginia.edu)
#
# The Zoom recording is in the Drive.
#
# ### Identify the Problem:
#
# ##### Problem Statement
#
# The current procedure for our car repair company, SOAC, is an analog
# accounting method with the results from this accounting residing in a
# SQL database without any complex analysis. Moreover, the organization of
# the data is appropriate but relatively complex, leading to negative
# consequences of the decisions based on this data, resulting in a
# relatively poor profit margin compared to SOAC’s rival car companies.
# Thus, the company has hired a group of system engineers (us) to diagnose
# and propose solutions to this problem by answering four questions:
# **“How can we increase the amount of revenue per transaction?**”, **“How
# can we optimize salaries to reduce expenses while improving profit?**”,
# **“What columns most closely correlate with expenses, and how do we
# optimize them?**”, “**What is the ratio of all expenses over revenue aka
# profit margin?”**.
#
# ##### Descriptive Analysis:
#
# SOAC has been suffering in recent years from a reduced margin of profit:
# many factors could be causing this decline in profit margin which
# threatens the company’s survival in this highly competitive, hostile
# market, particularly with inflation which further emphasizes the need
# for fixing this issue; however, we have a database which allows us to
# diagnose why the profit margin (mostly from sales and maintenance
# contracts) is relatively low compared with expenses (salaries, budget,
# marketing).
#
# ##### Stakeholders:
#
# The major stakeholders in this operation are - the employees, as their
# job performance based on our assessment could be affected by cost
# optimization; the business owners, as they have a direct interest in the
# version of SOAC; consumers, as the set of cars and the employees they
# buy from could be directly affected by the cost optimization and the
# survival of SOAC.
#
# ##### Normative Analysis:
#
# Suppose we successfully implement the solutions to the problems
# presented within the problem statement. In that case, the business’s
# profitability will increase, allowing SOAC to increase its margin and
# market share which might promote business growth and allow SOAC to
# weather the current hostile market and grow beyond its current size;
# ideally, it would be one of the few businesses that could benefit from
# the market instability.
#
# # Pipeline:
#
# ### Pipeline Architecture:
#
# The pipeline architecture consists of four main components: data
# extraction, data processing, data visualization, and data export. The
# data extraction component obtains data from SOAC databases and
# configures a database in a SQL server. The data processing component
# imports the data into an EC2 instance, connects to the SQL server via
# sqlalchemy, queries the data as needed, cleans the data using numpy, and
# imputes the data using sklearn. The data visualization component
# presents the data through a dashboard using streamlit. The data export
# component reexports any changes or transformations back into the EC2
# instance.
#
# ### Data Generation:
#
# Data was acquired from the classicmodels.sql used for in-class
# demonstrations and lectures through the first segment of the class.
#
# ### Data Processing:
#
# We used an entity-relationship diagram (ERD) to identify the relevant
# attributes of the payments entity for our data analysis project. The
# attributes were amount (DECIMAL) and payment date (DATE). We imported
# our data into an EC2 SQL database hosted on AWS, which enabled us to
# access the same database from different devices using a Jupyter Notebook
# and a secure connection with SQLalchemy. We then performed data cleaning
# on the data using the Numpy library. Our data cleaning strategies
# included:
#
# -   Deleting irrelevant data that did not pertain to our research questions
#
# -   Getting rid of duplicates that could skew our results
#
# -   Avoiding or converting data typos and similar errors that could affect data quality
#
# -   Creating data standards for naming conventions, capitalization, and formatting
#
# -   Taking care of missing values by imputing or dropping them based on the context
#
# We also checked for outliers and distribution of each variable using
# descriptive statistics, histograms, and boxplots. We then conducted our
# individual statistical analyses to answer our research questions. We
# used Python and graphing libraries to visualize the data and look for
# relationships among variables. We also performed feature extraction to
# create new variables from existing ones that could enhance our analysis.
# For example, we extracted the month and year from the payment date to
# examine seasonal patterns. Finally, we transformed the data into
# storable data types, such as png or .py files, and stored them in the
# SQL EC2 instance.
#
# Our data analysis process can be seen as a pipeline architecture, which
# is a series of steps that transform raw data into actionable insights.
# Each step in the pipeline has a specific function and output that feeds
# into the next step. A pipeline architecture helps us automate and
# streamline our data analysis workflow, as well as ensure data quality
# and consistency throughout the process.
#
# ### Serving:
#
# We used Streamlit, an open-source framework for data scientists to efficiently create interactive web-based data applications in pure Python, to build an interactive dashboard for data analysis on AWS. Streamlit allows us to easily display datasets, tables, charts, and widgets with minimal code. We also used Plotly, a Python library for creating interactive and high-quality graphs, to visualize our data and explore relationships among variables.
#
# Our dashboard has the following features:
# - A sidebar that lets the user select a series of graphs or datasets from a list of options that correlate directly in order to our questions.
# - A subpanel that shows the distribution plots, and correlation matrix of the selected dataset, if appropriate for the question.
# - A subpanel that allows the user to choose a target variable and a machine learning model (linear regression and random forest.)
# - A subpanel that displays the model performance metrics, feature importance and residual plots (R^2, MSE, MAE), if appropriate for the question.
#
# Our dashboard demonstrates various strategies for data exploration, such as:
#
# - Examining the variation in a single variable using histograms and boxplots
# - Exploring the combination of variables using scatter plots and heatmaps
# - Aggregating the data by grouping and summarizing using pandas
# - Modeling the data using scikit-learn and evaluating the model fit using metrics such as R-squared, mean squared error, and mean absolute error
#
#
# ![image1.png](attachment:image1.png)

# %% [markdown]
# ![image2.png](attachment:image2.png)

# %% [markdown]
# #### Summarization of Pipeline:
# Our data collection was minimal since we used the “classic models”
# database for our project. The ERD diagram of this data can be seen
# above. It represents the relationships between entities and the
# attributes associated with them. For example, the payments entity has
# the attributes of amount as a DECIMAL and payment date as a DATE. When
# deciding what data we wanted to work with to evaluate the company we
# were able to refer to the ERD and determine the attributes we had access
# to. We then imported our data into the EC2 SQL database which allowed
# each member of our group to access the same database through the jupyter
# notebook on different devices. This was accomplished through a secure
# connection using SQLalchemy. The data was then called and cleaned using
# the Numpy library where we dropped duplicates, consolidated redundant
# data, looked for null values, merged columns, and grouped by order
# number. On the newly cleaned data, we then performed our individual
# statistical analyses which answered each of our four questions. After
# the statistical analysis, we used Python and graphing libraries to
# visualize the data and look for relationships. The data was then
# transformed into storable data types, such as png or .py files, and in
# the SQL EC2 instance.
#
# With our findings, we made an interactive dashboard, which is included
# in our deliverable as a Python file.
#
# ### Implementation:
#
# ##  “How can we increase the amount of revenue per transaction?,”
#
# (Drake Ferri) we could leverage SQL’s ability to see relationships, so
# we could find what employees make the most money per transaction and how
# that correlates with their experience or other qualities in the
# database, allowing us to find which employees are increasing the margin
# and the opposite as well for hiring, promotion, and firing purposes.
#
# In order to increase the amount of revenue per transaction, we first
# wanted to look at the distribution of product orders. As can be seen
# from the Distribution of Product Orders histogram, the vast majority of
# orders contain anywhere from 20 to 50 car parts. Within these orders,
# though, the number of instances of each quantity is relatively similar.
#
# To continue, we needed to see the Distribution of Revenue. As can be
# seen in the histogram, we used sales as our axis. From the graph, it can
# be seen that the distribution of revenue per transaction falls primarily
# within the 2000-4000 range. However, the most common occurrence of sales
# revenue falls between the ranges of 3000-3400 dollars.

# %%
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly.express as px
connection_string = "mysql+pymysql://user:password@IP/Databasename"
engine = create_engine(connection_string)
query = 'SELECT * FROM payments'
df = pd.read_sql_query(sql=text(query), con=engine.connect())

engine = create_engine(connection_string)
query = 'SELECT * FROM orders INNER JOIN orderdetails ON orders.orderNumber = orderdetails.orderNumber;' # Inner Join
dfz = pd.read_sql_query(sql=text(query), con=engine.connect()) 
expenses = 0 
i = 0
for i in dfz:
    dfz['expenses'] =  (dfz['quantityOrdered'] * dfz['priceEach'])
expenses= round(sum(dfz['expenses']),2)
dfz = dfz.T.drop_duplicates().T
dfz1 = pd.merge(dfz, df, left_on='customerNumber', right_on = 'customerNumber', suffixes=('_x', '_y')) # Merge Dataframes!
dfz1 = dfz1.T.drop_duplicates().T # Remove duplicates
dfq = dfz1.groupby(["orderNumber"], as_index= 'TRUE').sum().reset_index()
dfq1 = dfz1.groupby(["paymentDate"], as_index= 'TRUE').sum().reset_index()

query = "SELECT * FROM customers INNER JOIN orders ON customers.customerNumber = orders.customerNumber"
dfconnection2 = pd.read_sql_query(sql=text(query), con=engine.connect())


# Question 1:
query = "SELECT * FROM orders INNER JOIN orderdetails ON orderdetails.orderNumber = orders.orderNumber"
dfconnection3 = pd.read_sql_query(sql=text(query), con=engine.connect())
dfconnection3 = dfconnection3.T.drop_duplicates().T
dfconnection3['sales'] = dfconnection3['quantityOrdered'] * dfconnection3['priceEach']
dfconnection3m = pd.merge(dfconnection3, dfconnection2, left_on='orderNumber', right_on = 'orderNumber', suffixes=('_x', '_y')) # Merge Dataframes!
dfconnection3m = dfconnection3m.T.drop_duplicates().T # Remove duplicates
new_df = dfconnection3[['orderNumber', 'sales']]
new_df = new_df.T.drop_duplicates().T
grouped_df = new_df.groupby("orderNumber", as_index = 'TRUE').mean().reset_index()

query = 'SELECT * FROM orderdetails'
orderDetails = pd.read_sql_query(sql=text(query), con=engine.connect())
expenses = 0 
i = 0
for i in orderDetails:
    orderDetails['expenses'] = (orderDetails['quantityOrdered'] * orderDetails['priceEach'])
    orderDetails['salary'] = round((orderDetails['quantityOrdered'] * orderDetails['priceEach'] * 0.20),2)
    dfconnection3m['salary'] = round((orderDetails['quantityOrdered'] * orderDetails['priceEach'] * 0.20),2)
expenses = sum(orderDetails['expenses'])
profit_margin = ((revenue - expenses) / expenses)
# Out:
# C:\Users\Gabriel Lawrence\AppData\Local\Temp\ipykernel_21648\181827266.py:23: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.add is deprecated. In a future version, a TypeError will be raised. Before calling .add, select only columns which should be valid for the function.
#
# C:\Users\Gabriel Lawrence\AppData\Local\Temp\ipykernel_21648\181827266.py:24: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.add is deprecated. In a future version, a TypeError will be raised. Before calling .add, select only columns which should be valid for the function.

# %%
px.histogram(grouped_df, x="sales", title ='Distribution of Sales')
# Out:
# <div>                            <div id="ae234324-ed00-4684-bb60-abb700d129d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae234324-ed00-4684-bb60-abb700d129d2")) {                    Plotly.newPlot(                        "ae234324-ed00-4684-bb60-abb700d129d2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sales=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2555.9574999999995,2637.2525,2747.39,3138.6843750000003,3092.7846153846153,3597.2806666666665,2897.322777777778,2786.5775000000003,3187.5762499999996,4305.5233333333335,3026.605625,2756.308333333334,3837.4700000000003,2761.07500000
# ...

# %%
px.histogram(dfq, x="quantityOrdered", title ='Distribution of Product Orders')
# Out:
# <div>                            <div id="5993a5dd-e361-4977-bca8-b29ec825f0f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5993a5dd-e361-4977-bca8-b29ec825f0f1")) {                    Plotly.newPlot(                        "5993a5dd-e361-4977-bca8-b29ec825f0f1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"quantityOrdered=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[453,568,240,2164,5759,2180,2025,687,1683,636,1710,651,104,1287,1053,630,108,1608,108,1326,2100,740,1635,468,1344,264,1851,2160,2041,1047,219,732,144,3718,681,5463,306,552,1260,798,1540,870,5193,1572,80,1689,228,1023,1720,
# ...

# %% [markdown]
# Although the quantity distribution is generally uniform, the revenue per
# transaction varies much more. This displays the concept of diminishing
# returns because as the quantity ordered increases, the revenue per
# transaction does not always follow the same trend. Therefore, increasing
# quantity ordered per transaction will not have the same effect on
# revenue per transaction. As a result, SOAC would benefit from finding
# the range of quantities in which revenue is maximized.
#
# Then, we wanted to find the relationship between the orders and
# employees tables. Through utilizing SQL’s join functions, we were able
# to group salary from commission with employee number. With python and
# its data visualization libraries (plotly), we were able to create a bar graph
# showing commission per employee.

# %%
px.bar(dfconnection3m, x= "salesRepEmployeeNumber", y = "salary", title ='Commissions per Employee')
# Out:
# <div>                            <div id="4c8af63e-c1b6-4aa7-86b1-5405de33cc71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c8af63e-c1b6-4aa7-86b1-5405de33cc71")) {                    Plotly.newPlot(                        "4c8af63e-c1b6-4aa7-86b1-5405de33cc71",                        [{"alignmentgroup":"True","hovertemplate":"salesRepEmployeeNumber=%{x}<br>salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1216,1216,1216,1216,1504,1504,1504,1504,1286,1286,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1504,1370,1370,1370,1370,1370,1370,1370,1370,1370,1370,1370,1370,1370,1401,1401,1
# ...

# %% [markdown]
# As can be seen in the graph, the commission amongst the employees ranges
# from around 75k to 250k. The average commission for these employees is
# in the 100k-150k range. In order to increase the revenue per
# transaction, SOAC can utilize the data in this chart to contemplate
# decisions regarding employees such as promotions or layoffs. For the
# sake of encouraging underperforming employees, one could use the mean of
# commissions as a benchmark when determining if an employee needs
# redirecting or not. From these changes, employees would be more
# motivated to earn more.
#
# With the combination of the employees being more motivated as well as
# finding the best range of quantities per order that maximizes revenue,
# SOAC would be able to drastically increase the revenue per transaction,
# in turn increasing the overall profit of the company.

# %% [markdown]
# ## “How can we optimize salaries to reduce expenses while improving profit?”
#
# (Camp Hagood) We can analyze the breakdown of each expense to make sure
# we are not spending money in unnecessary areas. To accomplish this we
# can perform a statistical analysis in SQL through variance analysis
# (SQL, VARIANCE()) and T-testing. This will give us insight into which
# salary ranges optimize performance on average, as it is known that lower
# salaries generally decrease the performance of employees and in turn
# reduce the profit margin and productivity.
#
# -   Historically, SOAC has used a commission system for paying and
#     > giving benefits to employees, with 30% of expenses associated with
#     > overall expenses going to salaries.
#
# To optimize salaries to reduce expenses while improving profit we
# created a plot of the mean and variance for each salary range using the
# plot function. For each salary range group, we calculated the mean price
# of products ordered along with the price for all order details that fell
# within that salary range group. We then used this information to obtain
# the mean product value for that salary range group. The resulting plot
# shows the mean product value for each salary range group, allowing us to
# compare the average performance of order details associated with
# different salary ranges. This allows us to analyze the breakdown of each
# expense so we can optimize employee salaries to make sure we are not
# spending money in unnecessary areas. For example, if we want an employee
# to order 6,000 dollars worth of usable car parts we would want to give them a
# salary in the range of 7,000- 8,000 dollars.

# %%
# Question 2 Code:
import sqlalchemy
from sqlalchemy import create_engine, text
import pandas as pd
import pymysql
connection_string = "mysql+pymysql://user:password@IP/Databasename"
engine = create_engine(connection_string)
query = 'SELECT * FROM orderdetails'
dfquestion2 = pd.read_sql_query(sql=text(query), con=engine.connect())
expenses = 0
i = 0
for i in dfquestion2:
    dfquestion2['product'] =  (dfquestion2['quantityOrdered'] * dfquestion2['priceEach'])
expenses= sum(dfquestion2['product'])
print(dfquestion2['product'])
# Group the data by salary ranges and calculate variance and mean
salary_ranges = pd.cut(dfquestion2['product'], bins=range(0, 15000, 1000), include_lowest=True)
grouped_data = dfquestion2.groupby(salary_ranges)['product'].mean()

# Plot the mean for each salary range
ax = grouped_data.plot(kind='bar', legend=False)
ax.set_ylabel('Mean Product')
ax.set_xlabel('Salary Range')
plt.show()
# Out:
# 0       4080.00
# 1       2754.50
# 2       1660.12
# 3       1729.21
# 4       2701.50
#          ...
# 2991    6261.71
# 2992     986.42
# 2993    3435.39
# 2994     553.52
# 2995    1708.56
# Name: product, Length: 2996, dtype: float64

# %% [markdown]
# ## “What factors most closely correlate with overall expenses, and how do we optimize them?”
#
# (Gabe Lawrence) we can combine multiple tables with join then use max()
# where there are cost or price columns to find which ones have the
# highest expenses and use our judgment and data processing methods to
# reduce costs like running covariance between revenue and costs and
# reducing the ones that have the least covariance (most negligible
# revenue to cost ratio, aka they only correlate to cost rather than
# revenue).
#
# Leverage the fact that the column, “customerNumbers,” is used in the
# database to link expenses and profit. Additionally, we need to use this
# SQL query to make the unified table “SELECT \* FROM orders INNER JOIN
# orderdetails ON orders.orderNumber = orderdetails.orderNumber;”
# Afterward we need to clean the data frame using drop_duplicates and
# group_by to make sure that customerNumbers works. Then normalize the
# vectors using standard scaling. Then we built a covariance matrix to
# determine if expenses could be reduced to improve profit:

# %%
# Question 3:
dfz1 = pd.merge(dfz, df, left_on='customerNumber', right_on = 'customerNumber', suffixes=('_x', '_y')) # Merge Dataframes!
dfz1 = dfz1.T.drop_duplicates().T # Remove duplicates
df = dfz1.groupby(["orderNumber"], as_index= 'TRUE').sum().reset_index()
dfq1 = dfz1.groupby(["paymentDate"], as_index= 'TRUE').sum().reset_index()

cols = ['quantityOrdered', 'priceEach', 'expenses', 'amount']
X = df[cols]
X_scaled = (X - X.mean(axis=0))/X.std(axis=0) # Scale and Normalize the values.
cov_matrix = X_scaled.cov()

import seaborn as sns
sns.set(font_scale=0.8)
sns.heatmap(cov_matrix, annot=True)
# Out:
# C:\Users\Gabriel Lawrence\AppData\Local\Temp\ipykernel_21648\160792604.py:4: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.add is deprecated. In a future version, a TypeError will be raised. Before calling .add, select only columns which should be valid for the function.
#
# C:\Users\Gabriel Lawrence\AppData\Local\Temp\ipykernel_21648\160792604.py:5: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.add is deprecated. In a future version, a TypeError will be raised. Before calling .add, select only columns which should be valid for the function.
#
# <frozen importlib._bootstrap>:228: RuntimeWarning:
#
# scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <AxesSubplot:>

# %% [markdown]
# As we can see from the covariance matrix above, SOAC needs to do two
# major things, reduce the expenses associated with each unit, and try to
# increase the quantity orders, as there is a strong correlation between
# profit \[amount\] and expenses with a 4% discrepancy, and in SOAC’s
# normative outcome, there would be a weaker correlation between the two
# as profit should be as decoupled from expenses as possible. A second
# hypothesis is that specific customers have a direct impact on the
# profitability of the business, so this analysis tested that through a
# modification of the categories tested:

# %%
cols = ['orderNumber', 'customerNumber', 'expenses', 'amount']
X = df[cols]
X_scaled = (X - X.mean(axis=0))/X.std(axis=0) # Scale and Normalize the values.
cov_matrix = X_scaled.cov()
print(cov_matrix)

import seaborn as sns
sns.set(font_scale=0.8)
sns.heatmap(cov_matrix, annot=True)
# Out:
#                 orderNumber  customerNumber  expenses    amount
# orderNumber        1.000000        0.043324  0.075852  0.075343
# customerNumber     0.043324        1.000000  0.787843  0.740640
# expenses           0.075852        0.787843  1.000000  0.963376
# amount             0.075343        0.740640  0.963376  1.000000
# <AxesSubplot:>

# %% [markdown]
# With this heatmap, there is a loose correlation between expenses and the
# customers tested, but there is no correlation to “orderNumber” \[which
# shows that the process is working and not giving out spurious
# correlations\], but there is a moderate correlation between expenses and
# “customerNumber” and this correlation is stronger than with SOAC’s
# profits, showing that SOAC’s client selection process might be a bit
# faulty, as this correlation should be reversed in a healthier business.

# %% [markdown]
# ## “What is the ratio of all expenses over revenue aka profit margin?”
#
# (Olivia Bernard) We can use SQL to calculate this by writing a script
# that sums the expenses and revenues and then divides the sum of
# expenditures by the sum of the revenues to get the profit margin.
#
# The data was first stored and extracted to SQL and AWS EC2. It was then
# transformed and cleaned on SQL. Then, I loaded the data using pandas and
# was able to analyze and visualize the data to answer the question.
#
# To analyze the data, I iterated through the table of purchases payments
# to sum together the purchases from customers to get revenue. The
# expenses were then calculated by iterating through the order details
# tables to multiple quantities of the items ordered by the price of the
# order to get the total amount of inventory bought. The revenues ended up
# totaling \$8,853,839.23 and the expenses were \$9,604,190.61. To
# visualize and compare these two:

# %%
query = 'SELECT * FROM employees'
dfquestion4 = pd.read_sql_query(sql=text(query), con=engine.connect())

query = 'SELECT * FROM payments'
dfquestion4a = pd.read_sql_query(sql=text(query), con=engine.connect())

revenue = sum(df.amount)

query = 'SELECT * FROM orderdetails'
dfquestion4b = pd.read_sql_query(sql=text(query), con=engine.connect())

expenses = 0 
i = 0
for i in dfquestion4b:
    dfquestion4b['product'] =  (dfquestion4b['quantityOrdered'] * dfquestion4b['priceEach'])
    
expenses = sum(dfquestion4b['product'])

profit_margin = ((revenue - expenses) / expenses)
print(profit_margin)

import matplotlib.pyplot as plt
plt.bar(['Revenue', 'Expenses'], [revenue, expenses])
plt.ylabel('Money')
plt.ylim(0, 10000000)
plt.title('Revenue vs. Expenses')
plt.show()
# Out:
# 53.629894004155005

# %% [markdown]
# numbers a bar chart was created using Python and matplotlib.
#
# Using this information the net profit margin metric was then calculated
# to answer the overall question. Net Profit Margin = (Revenue - Cost)/
# Revenue, and it was found that the net profit margin ratio is -0.07813
# or -7.81%. Net profit margin represents what percentage of sales has
# turned into profits which gives us insight into how successful SOAC is.
# A negative number indicates that production costs were more than revenue
# for this period. This is bad because it means that over time the company
# is likely to lose money instead of making a profit if it continues to
# order this much revenue while making this steady amount of revenue from
# sales. In order to make money the company should buy less inventory, buy
# from a different supplier so it is cheaper or reduce transportation
# costs and other costs associated with inventory. Alternatively, from the
# revenue side, SOAC should sell their product for more money in order to
# make more revenue and create a profit from their operation or they
# should sell more products to increase their revenue through volume. Most
# importantly, the company should work on its inventory handling and
# management procedures. They are not turning over inventory fast enough
# to be making a profit so it is possible that they are ordering the wrong
# inventory, too much or it, or the parts they are ordering are becoming
# obsolete after the order. This causes the company to lose money so
# managing the inventory better would greatly benefit the company.
#
# In the future to improve these results, instead of just looking at
# inventory for expenses I would also look at salaries expense, buildings,
# equipment, property, marketing, and other operating expenses. For
# expenses we only looked at the cost to acquire the inventory and the
# revenue was the profit made for selling the inventory. We also noticed
# that for car companies it is very hard to turnover a profit with
# merchandise each quarter because of how expensive the parts for a car
# are so a company must operate in the long term to make a profit.
#
# ## Conclusion:
#
# Our goal was to find ways to increase company profits through data
# analysis. According to this report’s data analysis, SOAC’s business
# model has several vital deficiencies that impede the normative outcomes:
# the prior inaccessibility of data for the business (which has been
# partially reduced by the existence of the dashboard), the poor
# recordkeeping has been a severe issue in achieving profitability and
# expansion, the problematic salary distribution reducing the performance
# of employees, the variety of inventory issues have all lead to SOAC
# being less competitive than its competitors and peers in the car sales
# market. To demonstrate these deficiencies this report presented and
# produced a variety of figures and recommendations for SOAC - with
# histograms, line graphs, and bar graphs through a data pipeline fueled
# by an EC2 instance running an MYSQL database being imported into Python
# through “sqlalchemy” along with recommendations based on this pipeline.
# Overall, the recommendations are to transition to a salary structure
# that increases the overall salary of SOAC employees, and SOAC needs to
# reduce the cost associated with the parts that it sells, SOAC needs to
# improve its body of clientele through advertisement and more targeted
# services for its customers. Thus, with this report’s recommendations,
# SOAC will be able to overcome the issues of the market and recover its
# sales figures to their peak during 2006 through a transformation of its
# implementation of the business without a severe shift in its markets.
